# %% [markdown]
# <a href="https://colab.research.google.com/github/imprincesarraf/face-detection-face-recognition-and-emotion-detection/blob/main/face_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cmake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 100.1 MB 22 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=a1f33c7fa536da43ec93905126c2e18f6ebc91d5022d24cfc1be97028a53fc2f
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %%
# !pip install dlib
import dlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 100.1 MB 23 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=f1ba4c83863d0ddfa805caea4a4717ff6df73fecf71838e25a91f05869a6f39f
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...

# %%
import face_recognition

# %%
import cv2
from google.colab.patches import cv2_imshow
img1=face_recognition.load_image_file('obama.jpg')
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
face=face_recognition.face_locations(img1)[0]
#print(face)
#face has been found next we have to encoding
encodeface=face_recognition.face_encodings(img1)[0]
#print(encodeface)
#it generates 128 unique features with the help of dlib library
cv2_imshow(img1)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=496x683 at 0x7F756DF98050>

# %%
img1test=face_recognition.load_image_file('obama1.jfif')
img1test=cv2.cvtColor(img1test,cv2.COLOR_BGR2RGB)
cv2_imshow(img1test)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=192x262 at 0x7F759E0E9510>

# %%
result=face_recognition.compare_faces
